# %%
import torch
import torch.nn.functional as F
import numpy as np

MODEL_FP = '/home/cdonahue/txl/transformer-xl/models/papermodels/finetune400k/model.pt'
VOCAB_FP = '/home/cdonahue/txl/transformer-xl/models/papermodels/finetune400k/vocab.txt'
USE_CUDA = True

device = torch.device("cuda" if USE_CUDA else "cpu")

# Load the best saved model.
with open(MODEL_FP, 'rb') as f:
    model = torch.load(f)
model.backward_compatible()
model = model.to(device)

# Make sure model uses vanilla softmax.
if model.sample_softmax > 0:
  raise NotImplementedError()
if model.crit.n_clusters != 0:
  raise NotImplementedError()

model.eval()

# Load the vocab.
idx2sym = ['<S>']
with open(VOCAB_FP, 'r') as f:
  for line in f:
    idx2sym.append(line.strip().split(',')[-1])
sym2idx = {s:i for i, s in enumerate(idx2sym)}
wait_amts = set([int(s[3:]) for s in idx2sym if s[:2] == 'WT'])
print(len(idx2sym))
# Out:
# /home/cdonahue/txl/lib/python3.5/site-packages/torch/serialization.py:435: SourceChangeWarning: source code of class 'mem_transformer.MemTransformerLM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# 631

# %%
TX1_PATH = '/home/cdonahue/txl/transformer-xl/data/03_12_00_comp_pianorange/test/*.tx1.txt'

import glob as glob
import os

TX1_FPS = sorted(glob.glob(TX1_PATH))

fn_to_ids = {}
fn_to_nsamps = {}
fn_to_len = {}
for fp in TX1_FPS:
    fn = os.path.split(fp)[1].split('.')[0]
    with open(fp, 'r') as f:
        prime = ['<S>'] + f.read().strip().splitlines() + ['<S>']

    prime_ids = []
    w = 0
    for s in prime:
        if s in sym2idx:
            prime_ids.append(sym2idx[s])
        else:
            assert s[:2] == 'WT'
            wait_amt = int(s.split('_')[1])
            w += wait_amt
            closest = min(wait_amts, key=lambda x:abs(x - wait_amt))
            prime_ids.append(sym2idx['WT_{}'.format(closest)])
    
    fn_to_ids[fn] = prime_ids
    fn_to_len[fn] = len(prime_ids)
    fn_to_nsamps[fn] = w

# %%
# REFERENCE EVALUATION METHOD... PRODUCES IDENTICAL RESULT TO TRAINING CODE EVAL

def eval_seq(seq_id, tgt_len=128, mem_len=896):
    # Set model to eval mode to turn off dropout.
    model.eval()
    
    # Modify length to specified sequence / memory length.
    EXT_LEN = 0
    model.reset_length(tgt_len, EXT_LEN, mem_len)
    
    # Slice up sequence into inputs and targets.
    inputs = seq_id[:-1]
    targets = seq_id[1:]
    
    with torch.no_grad():
        # Init (empty) memory.
        mems = []
        
        total_len = 0
        total_loss = 0.
        for i in range(0, len(inputs), tgt_len):
            # Take (up to) tgt_len tokens from input and targets
            _inp = inputs[i:i+tgt_len]
            _tar = targets[i:i+tgt_len]
            assert len(_inp) == len(_tar)
            numvalid = len(_inp)
            
            # Pad input into buffer of size [tgt_len, 1].
            _inp = np.array(_inp, dtype=np.int64)[:, np.newaxis]
            _inp = np.pad(_inp, [[0, tgt_len - numvalid], [0, 0]], 'constant')
            inp = torch.from_numpy(_inp).to(device)
            
            # Pad target into buffer of size [tgt_len, 1].
            _tar = np.array(_tar, dtype=np.int64)[:, np.newaxis]
            _tar = np.pad(_tar, [[0, tgt_len - numvalid], [0, 0]], 'constant')
            tar = torch.from_numpy(_tar).to(device)
            
            # Evaluate the model, saving its memory.
            #print(i + tgt_len, mems[0].shape if len(mems) else None, mems[1][0, 0, 34] if len(mems) else None)
            ret = model.forward_generate(inp, *mems)
            logits, mems = ret[0], ret[1:]
            
            vocabsize = int(logits.shape[-1])
            logprobs = F.log_softmax(logits, dim=-1)
            
            logprobs_flat = logprobs.view(-1, vocabsize)
            tar_flat = tar.view(-1)
            nll = -torch.gather(logprobs_flat, -1, tar).view(tgt_len, 1)
            loss = nll
            
            # Discard invalid steps for incomplete chunks.
            loss = loss[:numvalid]
            
            # Add to total loss and length.
            total_loss += loss.sum().float().item()
            total_len += numvalid
        
    return total_len, total_loss

# %%
import os
from tqdm import tqdm

fn_to_len_loss = {}
with torch.no_grad():
    total_len = 0
    total_loss = 0.
    for fp, ids in tqdm(fn_to_ids.items()):
        fn = os.path.split(fp)[1].split('.')[0]
        seq_len, seq_loss = eval_seq(ids, tgt_len=512, mem_len=896)
        fn_to_len_loss[fn] = (seq_len, seq_loss)
        total_len += seq_len
        total_loss += seq_loss
    print(np.exp(total_loss / total_len))
# Out:
# 100%|██████████| 373/373 [00:22<00:00, 16.61it/s]
# 2.4519956105711924

# %%
all_fn_to_len_loss = fn_to_len_loss

print('-' * 80)
print('Highest likelihood')
for fn, (seqlen, seqloss) in sorted(fn_to_len_loss.items(), key=lambda x: x[1][1] / x[1][0]):
    print('{:.2f}'.format(np.exp(seqloss / seqlen)), fn_to_len[fn], fn_to_nsamps[fn] / 44100., fn)

    """
print('-' * 80)
print('Lowest likelihood')
for fn, (seqlen, seqloss) in sorted(fn_to_len_loss.items(), key=lambda x: -x[1][1] / x[1][0])[:32]:
    print('{:.2f}'.format(np.exp(seqloss / seqlen)), fn_to_len[fn], fn_to_nsamps[fn] / 44100., fn)
    """
# Out:
# --------------------------------------------------------------------------------
# Highest likelihood
# 1.32 519 32.179591836734694 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_19_20Area43
# 1.32 3411 93.62310657596372 194_KnightMove_05_06HighScoreBoard
# 1.33 3290 37.57673469387755 071_DigitalDevilStory_MegamiTensei_06_07VienVienCity
# 1.36 4033 76.21514739229025 071_DigitalDevilStory_MegamiTensei_16_17AnfiniAnfiniPalace
# 1.41 2580 89.0362358276644 038_BubbleBobble_05_06RealEnding
# 1.44 273 8.533061224489796 237_MightyBombJack_05_06Labyrinth
# 1.45 5941 83.63249433106576 145_Golgo13_TopSecretEpisode_20_21Ending
# 1.45 2755 49.64598639455782 241_MiracleRopit_sAdventurein2100_06_07ThemeoftheOldCastleandLake
# 1.46 2742 87.79551020408164 286_Rygar_19_20Ending
# 1.47 600 9.750907029478459 071_DigitalDevilStory_MegamiTensei_07_08WindowLightShop
# 1.49 1868 28.377936507936507 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai
# 3.52 210 3.4441950113378685 092_DuckHunt_02_03RoundClear
# 3.52 557 5.159569160997733 272_Quarth_05_06GameOver
# 3.58 93 7.468571428571429 145_Golgo13_TopSecretEpisode_12_13Cutscene5SniperStage3Dungeon1
# 3.58 188 2.590045351473923 389_WreckingCrew_03_04GameOver
# 3.59 370 12.715646258503401 016_ArkanoidII_05_06Ending
# 3.61 269 7.793514739229025 256_OperationWolf_01_02OperationStart
# 3.63 220 2.3272789115646257 013_AlterEgo_09_10LevelClearUnused
# 3.65 110 1.7932879818594105 379_WardnernoMori_05_06GameOver
# 3.66 897 47.486553287981856 002_1943_TheBattleofMidway_13_14Ending
# 3.66 632 23.718888888888888 176_InsectorX_01_02DesertAreaRound11
# 3.67 97 1.063718820861678 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_10_11Area24
# 3.67 350 13.070861678004535 071_DigitalDevilStory_MegamiTensei_12_13PrayJakyou
# 3.68 600 22.373401360544218 145_Golgo13_TopSecretEpisode_10_11ShootingstageDungeon2ActionStage5
# 3.68 402 6.988458049886622 002_1943_TheBattleofMidway_02_03MissionStart
# 3.70 321 8.405079365079365 256_OperationWolf_02_03MissionAccomplished1
# 3.70 703 22.31421768707483 176_InsectorX_04_05CityAreaRound31
# 3.71 1669 46.305192743764174 242_MississippiSatsujinJiken_00_01MainTheme
# 3.72 291 9.429727891156462 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_02_03Area12
# 3.73 1200 28.648027210884354 037_BoobyKids_04_05BreakTime
# 3.78 528 6.199750566893424 002_1943_TheBattleofMidway_05_06MissionCompletedI
# 3.81 3504 31.007437641723357 013_AlterEgo_05_06Level4
# 3.82 802 44.897233560090704 194_KnightMove_06_07ChampionScore
# 3.90 2919 55.49727891156463 037_BoobyKids_05_06FunnyDragon
# 3.90 1185 29.30455782312925 183_Karnov_01_02KarnovTheme
# 3.91 2463 55.356031746031746 037_BoobyKids_08_09WildStreet
# 3.93 466 1.8277097505668933 286_Rygar_18_19LigarLastBoss
# 3.95 1901 32.83755102040816 116_FelixtheCat_00_01TitleScreen
# 3.96 183 1.8409977324263038 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_28_29Jingle4
# 3.97 151 1.5914512471655329 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_25_26Jingle1
# 4.00 309 10.626916099773243 176_InsectorX_12_13NameEntry
# 4.05 167 6.28108843537415 308_StarForce_02_03Purser
# 4.07 63 1.8549433106575963 128_FormationZ_01_02Start
# 4.08 295 8.83283446712018 145_Golgo13_TopSecretEpisode_18_19Brain
# 4.13 234 31.61310657596372 194_KnightMove_00_01MenuOption
# 4.17 430 16.001201814058955 183_Karnov_05_06FinalBattle
# 4.19 231 6.339705215419501 256_OperationWolf_05_06Unknown
# 4.19 231 5.569433106575964 145_Golgo13_TopSecretEpisode_21_22ToBeContinued
# 4.22 1218 7.671201814058957 071_DigitalDevilStory_MegamiTensei_00_01Title
# 4.23 1374 9.855555555555556 272_Quarth_03_04TheClosingGameintheUniverse
# 4.25 259 5.584920634920635 374_Vs_DuckHunt_04_05ClayShootingStart
# 4.30 242 10.197641723356009 308_StarForce_00_01Start
# 4.30 207 1.607437641723356 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_26_27Jingle2
# 4.31 145 0.9275056689342404 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_06_07Elevator
# 4.33 1239 30.84267573696145 242_MississippiSatsujinJiken_10_11MainThemeExtended
# 4.33 187 35.93702947845805 286_Rygar_04_05IndoraGod
# 4.34 1795 37.09204081632653 037_BoobyKids_07_08BoobyMarch
# 4.40 736 12.528163265306123 265_PokerJ_ngl_ng_07_08WonAgainstRukaFullHouseFrancine
# 4.43 82 9.764126984126984 237_MightyBombJack_04_05StageClear
# 4.45 884 17.634625850340136 183_Karnov_06_07AllCleared
# 4.47 78 5.911836734693877 164_Hogan_sAlley_04_05ScenaryScrolling
# 4.49 174 5.591201814058957 040_BurgerTime_01_02MainTheme
# 4.50 1359 38.30469387755102 116_FelixtheCat_06_07UnderwaterPlanet
# 4.50 107 14.922607709750567 145_Golgo13_TopSecretEpisode_06_07Cutscene2
# 4.50 190 3.719138321995465 092_DuckHunt_00_01TitleScreen
# 4.56 217 0.6435147392290249 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_12_13Area31
# 4.68 365 6.084036281179138 374_Vs_DuckHunt_01_02GameStart
# 4.68 420 15.963514739229025 176_InsectorX_05_06IntheSewersRound32
# 4.70 882 49.61884353741497 194_KnightMove_08_092PlayersWin
# 4.71 121 4.247687074829932 242_MississippiSatsujinJiken_01_02DizzysTheme
# 4.75 463 20.451337868480724 176_InsectorX_03_04PlateauAreaRound2
# 4.79 214 3.4258956916099774 092_DuckHunt_03_04GameOver
# 4.80 545 25.324195011337867 176_InsectorX_06_07JungleAreaRound41
# 4.83 485 7.986666666666666 256_OperationWolf_03_04MissionAccomplished2
# 4.99 761 16.144263038548754 037_BoobyKids_00_01TitleScreen
# 4.99 163 38.33047619047619 286_Rygar_13_14DoragosPalaceJPVersion
# 5.07 59 4.058004535147393 286_Rygar_16_17PegasusFlute
# 5.10 323 4.336575963718821 071_DigitalDevilStory_MegamiTensei_05_06GameOver
# 5.11 183 24.55235827664399 016_ArkanoidII_04_05DOHDominateOverHour
# 5.15 461 6.233265306122449 002_1943_TheBattleofMidway_06_07FailedintheAttack
# 5.21 404 23.871201814058956 214_MadoolanoTsubasa_08_09Ending
# 5.26 166 3.6043990929705214 040_BurgerTime_00_01RoundStart
# 5.33 148 6.104535147392291 242_MississippiSatsujinJiken_06_07WilliamsTheme
# 5.39 205 5.792585034013605 015_Arkanoid_00_01GameStart
# 5.39 407 14.64140589569161 183_Karnov_07_08NameEntry
# 5.48 135 37.929433106575964 286_Rygar_05_06IndoraGodJPVersion
# 5.49 526 9.692562358276644 290_Seicross_02_03StageClear
# 5.49 303 7.127687074829932 164_Hogan_sAlley_03_04GoodShooting
# 5.58 173 5.657074829931973 015_Arkanoid_02_03DohRound
# 5.63 115 14.922766439909298 145_Golgo13_TopSecretEpisode_22_23Unused1
# 5.67 153 6.5233106575963715 164_Hogan_sAlley_06_07GameOver
# 5.85 99 6.962789115646259 214_MadoolanoTsubasa_01_02Start
# 5.91 150 0.9480498866213152 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_07_08Area21
# 5.99 336 7.674648526077098 265_PokerJ_ngl_ng_09_10WonAgainstAyamiPokerPenny
# 6.07 114 0.5177777777777778 016_ArkanoidII_00_01Coin
# 6.11 141 3.5817687074829934 285_Route16Turbo_05_06Clear2
# 6.14 103 3.828526077097506 038_BubbleBobble_07_08GameOver
# 6.27 54 2.4844444444444442 040_BurgerTime_03_04Death
# 6.43 168 5.6007256235827665 164_Hogan_sAlley_02_03RoundStart
# 6.44 475 25.522766439909297 176_InsectorX_10_11TheirEmpireRound5Ending
# 6.44 269 7.829795918367347 164_Hogan_sAlley_00_01TitleScreen
# 6.50 115 4.632040816326531 361_Transformers_ConvoynoNazo_07_08GameOver
# 6.55 142 8.977641723356008 242_MississippiSatsujinJiken_05_06NelsonsTheme
# 6.57 99 12.593560090702947 145_Golgo13_TopSecretEpisode_16_17EveChristy
# 6.62 184 4.614240362811791 374_Vs_DuckHunt_00_01Title
# 6.71 144 2.5465986394557825 389_WreckingCrew_01_02PhaseClear
# 6.78 81 2.660249433106576 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_08_09Area22
# 6.87 157 12.707256235827664 285_Route16Turbo_06_07GameOver
# 6.97 214 3.3925170068027213 176_InsectorX_00_01RoundStart
# 7.00 328 7.387256235827665 183_Karnov_04_05HurryUp
# 7.15 212 12.101315192743764 242_MississippiSatsujinJiken_04_05HelensTheme
# 7.23 63 1.2613151927437642 237_MightyBombJack_15_16Jingle2
# 7.35 333 6.094739229024944 338_TerraCresta_00_01GameStart
# 7.36 159 3.5167573696145125 183_Karnov_02_03PlayerOut
# 7.41 138 3.893265306122449 164_Hogan_sAlley_05_06TrickShotRoundClear
# 7.42 145 4.130022675736962 290_Seicross_00_01Start
# 7.51 71 2.371972789115646 265_PokerJ_ngl_ng_03_04PokerJinglingMainBGM
# 7.55 52 2.597573696145125 052_Choplifter_02_03RoundClear
# 7.62 118 6.736530612244898 128_FormationZ_00_01TitleScreen
# 7.63 55 1.8629931972789116 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_01_02Area11
# 7.77 81 3.7866666666666666 237_MightyBombJack_12_13GameOver
# 8.00 55 1.5514512471655328 286_Rygar_20_21GameOver
# 8.17 135 3.787074829931973 290_Seicross_04_05Extend
# 8.34 209 6.4570748299319725 338_TerraCresta_07_08GameOver
# 8.36 33 0.8096598639455782 237_MightyBombJack_07_08TortureRoom
# 8.37 172 0.6383673469387755 145_Golgo13_TopSecretEpisode_00_01VicTokaiLogo
# 8.53 136 4.878888888888889 242_MississippiSatsujinJiken_02_03TaylorsTheme
# 8.60 88 2.1332879818594104 374_Vs_DuckHunt_07_08RoundStart
# 8.73 287 5.9058049886621315 037_BoobyKids_03_04RoundClear
# 8.74 82 1.3950566893424037 176_InsectorX_11_12GameOver
# 8.77 112 3.8989569160997735 285_Route16Turbo_04_05Clear1
# 8.83 109 26.623038548752834 052_Choplifter_01_02MainBGM
# 9.26 141 1.0445351473922901 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_14_15Area33
# 9.29 37 2.622766439909297 015_Arkanoid_04_05GameOver
# 9.92 207 4.127142857142857 374_Vs_DuckHunt_08_09GameOver
# 10.39 102 10.639501133786847 242_MississippiSatsujinJiken_07_08HenrysTheme
# 10.58 105 6.386984126984127 242_MississippiSatsujinJiken_03_04CartersTheme
# 10.69 159 4.842063492063492 338_TerraCresta_03_04LastStart
# 10.98 103 1.7932426303854876 016_ArkanoidII_06_07GameOver
# 11.02 43 6.389614512471655 145_Golgo13_TopSecretEpisode_08_09Cutscene3
# 11.06 107 2.845873015873016 016_ArkanoidII_03_04GetReady
# 11.20 56 2.130861678004535 237_MightyBombJack_06_07Penalty
# 11.36 36 1.5765079365079364 286_Rygar_12_13DoragosPalace
# 11.57 46 8.449795918367347 194_KnightMove_01_02Start
# 12.35 217 5.055079365079365 116_FelixtheCat_13_14GameOver
# 12.36 60 1.994965986394558 374_Vs_DuckHunt_02_03DuckDead
# 12.39 89 14.923038548752835 145_Golgo13_TopSecretEpisode_14_15HerodesConcertHall
# 13.24 126 5.590907029478458 290_Seicross_06_07GameOver
# 13.32 72 3.8474603174603175 361_Transformers_ConvoynoNazo_01_02StageStart
# 13.41 117 3.6858049886621314 116_FelixtheCat_11_12RoundClear
# 13.50 103 3.9838548752834466 176_InsectorX_09_10RoundClear
# 14.13 121 3.4558503401360543 015_Arkanoid_01_02RoundStart
# 14.22 153 4.170521541950113 085_DragonBusterII_YaminoFuuin_02_03RoundStart
# 14.40 91 14.923083900226757 145_Golgo13_TopSecretEpisode_09_10Cutscene4
# 14.55 25 0.5323809523809524 242_MississippiSatsujinJiken_09_10GetEvidence
# 14.59 54 1.9237414965986395 265_PokerJ_ngl_ng_06_07Won
# 14.60 142 4.4714285714285715 037_BoobyKids_11_12GameOver
# 14.94 16 1.3299092970521542 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_21_22Area4Battle
# 15.06 55 1.3303854875283447 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_03_04Area13
# 15.69 39 4.642879818594104 214_MadoolanoTsubasa_07_08StageClear
# 16.06 16 1.3301133786848072 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_16_17Area3Battle
# 16.59 81 3.8287301587301585 290_Seicross_05_06Miss
# 17.24 26 6.3894784580498865 214_MadoolanoTsubasa_05_06ItemRoom
# 18.32 61 2.517891156462585 265_PokerJ_ngl_ng_02_03GameStart
# 18.93 26 5.385827664399093 214_MadoolanoTsubasa_09_10GameOver
# 19.07 66 2.923310657596372 338_TerraCresta_02_03Restart
# 20.01 97 3.6300907029478457 183_Karnov_03_04Clear
# 22.66 98 4.013356009070295 040_BurgerTime_02_03RoundClear
# 24.23 16 1.346485260770975 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_05_06Area1Battle
# 25.12 45 4.706281179138322 183_Karnov_08_09GameOver
# 25.40 31 0.9495238095238095 237_MightyBombJack_14_15Jingle1
# 26.21 71 2.1163038548752833 085_DragonBusterII_YaminoFuuin_11_12GameOver
# 33.78 95 2.944920634920635 037_BoobyKids_01_02RoundStart
# 42.81 10 0.6973469387755102 158_HikarinoSenshiPhoton_WakuseiZoldiasnoTatakai_11_12Area2Battle
# 45.19 46 4.25907029478458 242_MississippiSatsujinJiken_08_09CrimeSceneTrap
# 61.02 15 1.8343764172335602 374_Vs_DuckHunt_03_04DuckFlyAway
# 7489.04 3 1.424263038548753 141_Ghostbusters_00_01Ghostbusters
